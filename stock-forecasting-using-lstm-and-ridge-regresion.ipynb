# %% [markdown]
# # **Importing Necessary Modules**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential 
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge


from numpy.random import seed
seed(69)

# %% [markdown]
# # **Exploring the Data**

# %%
data = pd.read_csv("/kaggle/input/apple-stock-data-updated-till-22jun2021/AAPL.csv", parse_dates=['Date'])
data.head(10)
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600
# 5 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.098578   48630400
# 6 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.103376   37363200
# 7 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.107739   46950400
# 8 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.113409   48003200
# 9 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.123877   55574400

# %%
data['year'] = data['Date'].dt.year
data['month'] = data['Date'].dt.month
data['Open Price Change'] = data['Open'].diff()

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600
#
#    year  month  Open Price Change
# 0  1980     12                NaN
# 1  1980     12          -0.006138
# 2  1980     12          -0.008929
# 3  1980     12           0.002232
# 4  1980     12           0.003349

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(y = data['Volume'], x= data['year'])
plt.title("Volume trend over time")
# Out:
# Text(0.5, 1.0, 'Volume trend over time')

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(y = data['Adj Close'], x= data['year'])
plt.title("Adj Close trend over time")
# Out:
# Text(0.5, 1.0, 'Adj Close trend over time')

# %%
open_price = go.Waterfall(x = data['Date'], y = data['Open Price Change'], 
                         decreasing = {'marker': {'color': 'red'}},
                          increasing = {'marker': {'color': 'green'}})

layout = go.Layout(title = 'Apple Open Price Change Waterfall',
                  xaxis = dict(title = 'Date'), yaxis = dict(title = 'Open Price Change'), 
                  xaxis_tickangle = 45)

fig = go.Figure(data = [open_price], layout = layout)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2cdebfd9-2ae4-4b2b-8cd0-5ebe6d6873db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cdebfd9-2ae4-4b2b-8cd0-5ebe6d6873db")) {                    Plotly.newPlot(                        "2cdebfd9-2ae4-4b2b-8cd0-5ebe6d6873db",                        [{"decreasing":{"marker":{"color":"red"}},"increasing":{"marker":{"color":"green"}},"x":["1980-12-12T00:00:00","1980-12-15T00:00:00","1980-12-16T00:00:00","1980-12-17T00:00:00","1980-12-18T00:00:00","1980-12-19T00:00:00","1980-12-22T00:00:00","1980-12-23T00:00:00","1980-12-24T00:00:00","1980-12-26T00:00:00","1980-12-29T00:00:00","1980-12-30T00:00:00","1980-12-31T00:00:00","1981-01-02T00:00:00","1981-01-05T00:00:00","1981-01-06T00:00:00","1981-01-07T00:00:00","1981-01-08T00:00:00","1981-01-09T00:00:00","1981-01-12T00:00:00","1981-01-13T00:00:00","1981-01-14T00:00:00","1981-01-15T00:00:00","1981-01-16T00:00:00","1981-01-19T00:00:00","1981-01-20T00:00:00","1981-01-21T00:00:00","1981-01-22T00:00:00","1981-01-23T00:00:00","1981-01-26T00:00:00","1981-01-27T00:00:00","1981-01-28T00:00:00","1981-01-29T00:00:00","1981-01-30T00:00:00","1981-02-02T00:00:00","1981-02-03T00:00:00","1981-02-04T00:00:00","1981-02-05T00:00:00","1981-02-06T00:00:00","1981-02-09T00:00:00","1981-02-10T00:00:00","1981-02-11T00:00:00","1981-02-12T00:00:00","1981-02-13T00:00:00","1981-02-17T00:00:00","1981-02-18T00:00:00","1981-02-19T00:00:00","1981-02-20T00:00:00","1981-02-23T00:00:00","1981-02-24T00:00:00","1981-02-25T00:00:00","1981-02-26T00:00:00","1981-02-27T00:00:00","1981-03-02T00:00:00","1981-03-03T00:00:00","1981-03-04T00:00:00","1981-03-05T00:00:00","1981-03-06T00:00:00","1981-03-09T00:00:00","1981-03-10T00:00:00","1981-03-11T00:00:00","1981-03-12T00:00:00","1981-03-13T00:00:00","1981-03-16T00:00:00","1981-03-17T00:00:00","1981-03-18T00:00:00","1981-03-19T00:00:00","1981-03-20T00:00:00","1981-03-23T00:00:00","1981-03-24T00:00:00","1981-03-25T00:00:00","1981-03-26T00:00:00","1981-03-27T00:00:00","1981-03-30T00:00:00","1981-03-31T00:00:00","1981-04-01T00:00:00","1981-04-02T00:00:00","1981-04-03T00:00:00","1981-04-06T00:00:00","1981-04-07T00:00:00","1981-04-08T00:00:00","1981-04-09T00:00:00","1981-04-10T00:00:00","1981-04-13T00:00:00","1981-04-14T00:00:00","1981-04-15T00:00:00","1981-04-16T00:00:00","1981-04-20T00:00:00","1981-04-21T00:00:00","1981-04-22T00:00:00","1981-04-23T00:00:00","1981-04-24T00:00:00","1981-04-27T00:00:00","1981-04-28T00:00:00","1981-04-29T00:00:00","1981-04-30T00:00:00","1981-05-01T00:00:00","1981-05-04T00:00:00","1981-05-05T00:00:00","1981-05-06T00:00:00","1981-05-07T00:00:00","1981-05-08T00:00:00","1981-05-11T00:00:00","1981-05-12T00:00:00","1981-05-13T00:00:00","1981-05-14T00:00:00","1981-05-15T00:00:00","1981-05-18T00:00:00","1981-05-19T00:00:00","1981-05-20T00:00:00","1981-05-21T00:00:00","1981-05-22T00:00:00","1981-05-26T00:00:00","1981-05-27T00:00:00","1981-05-28T00:00:00","1981-05-29T00:00:00","1981-06-01T00:00:00","1981-06-02T00:00:00","1981-06-03T00:00:00","1981-06-04T00:00:00","1981-06-05T00:00:00","1981-06-08T00:00:00","1981-06-09T00:00:00","1981-06-10T00:00:00","1981-06-11T00:00:00","1981-06-12T00:00:00","1981-06-15T00:00:00","1981-06-16T00:00:00","1981-06-17T00:00:00","1981-06-18T00:00:00","1981-06-19T00:00:00","1981-06-22T00:00:00","1981-06-23T00:00:00","1981-06-24T00:00:00","1981-06-25T00:00:00","1981-06-26T00:00:00","1981-06-29T00:00:00","1981-06-30T00:00:00","1981-07-01T00:00:00","1981-07-02T00:00:00","1981-07-06T00:00:00","1981-07-07T00:00:00","1981-07-08T00:00:00","1981-07-09T00:00:00","1981-07-10T00:00:00","1981-07-13T00:00:00","1981-07-14T00:00:00","1981-07-15T00:00:00","1981-07-16T00:00:00","1981-07-17T00:00:00","1981-07-20T00:00:00","1981-07-21T00:00:00","1981-07-22T00:00:00","1981-07-23T00: ...

# %% [markdown]
# # **Predicting Opening Value**

# %% [markdown]
# **Preparing Train Data**

# %%
df_apple = pd.read_csv("../input/apple-stock-data-updated-till-22jun2021/AAPL.csv")
df_apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
df_apple['Date'] = pd.to_datetime(df_apple['Date'], format="%Y-%m-%d")

# %%
open_price=df_apple.loc[:,'Open'].to_numpy()

# %%
open_price = open_price.reshape(-1, 1)
train_set = open_price[:7000]
valid_set = open_price[7000:8000]
test_set = open_price[8000:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_valid = MinMaxScaler(feature_range=(0, 1))
sc_test = MinMaxScaler(feature_range=(0, 1))

train_set_scaled = sc.fit_transform(train_set)
valid_set_scaled = sc_valid.fit_transform(valid_set)
test_set_scaled = sc_test.fit_transform(test_set)

# %%
def generate_data(data, window_size_input = 300):
    X = []
    y = []
    for i in range(window_size_input, len(data)):
        # Get the data 
        X_data = data[i - window_size_input : i, 0]
        y_data = data[i, 0]
        X.append(X_data)
        y.append(y_data)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE_SEARCH = 300

X_train, y_train = generate_data(train_set_scaled, WINDOW_SIZE_SEARCH)
X_valid, y_valid = generate_data(valid_set_scaled, WINDOW_SIZE_SEARCH)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %% [markdown]
# **Making Model**

# %%
model_1_open = Sequential()

model_1_open.add(LSTM(256, return_sequences=False, input_shape= (X_train.shape[1], 1)))
model_1_open.add(Dense(128))
model_1_open.add(Dense(64))
model_1_open.add(Dense(1))

model_1_open.compile(optimizer = 'adam', loss = 'mean_squared_error',)

# %%
hist = model_1_open.fit(X_train, y_train, epochs = 10, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/10
# 105/105 - 85s - loss: 8.2293e-04 - 85s/epoch - 810ms/step
# Epoch 2/10
# 105/105 - 78s - loss: 8.7783e-05 - 78s/epoch - 740ms/step
# Epoch 3/10
# 105/105 - 81s - loss: 8.2965e-05 - 81s/epoch - 771ms/step
# Epoch 4/10
# 105/105 - 87s - loss: 1.2843e-04 - 87s/epoch - 829ms/step
# Epoch 5/10
# 105/105 - 86s - loss: 7.3848e-05 - 86s/epoch - 818ms/step
# Epoch 6/10
# 105/105 - 85s - loss: 9.0813e-05 - 85s/epoch - 812ms/step
# Epoch 7/10
# 105/105 - 85s - loss: 5.4283e-05 - 85s/epoch - 812ms/step
# Epoch 8/10
# 105/105 - 87s - loss: 8.0289e-05 - 87s/epoch - 832ms/step
# Epoch 9/10
# 105/105 - 82s - loss: 6.4654e-05 - 82s/epoch - 781ms/step
# Epoch 10/10
# 105/105 - 79s - loss: 6.5192e-05 - 79s/epoch - 756ms/step

# %%
plt.plot(hist.history['loss'])
plt.title('Loss from the Training Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc = 'upper left')
plt.show()

# %%
pred_price_train=model_1_open.predict(X_train)
# Out:
# 210/210 [==============================] - 42s 198ms/step

# %%
y_train=y_train.reshape(len(y_train),1)

# %%
y_2_train=y_train-pred_price_train

# %%
model_2_open=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_2_open.fit(X_train,y_2_train)
y_2_pred=model_2_open.predict(X_train)
pred_price_train+=y_2_pred

# %%
y_3_train=y_train-pred_price_train

# %%
model_3_open=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_3_open.fit(X_train,y_3_train)
y_3_pred=model_3_open.predict(X_train)
pred_price_train+=y_3_pred

# %%
y_4_train=y_train-pred_price_train

# %%
model_4_open=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_4_open.fit(X_train,y_4_train)
y_4_pred=model_4_open.predict(X_train)
pred_price_train+=y_4_pred

# %%
print(mean_squared_error(pred_price_train,y_train))
# Out:
# 2.8355839242767758e-05

# %% [markdown]
# **Preparing Validation Data**

# %%
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1],1))
price_prediction = model_1_open.predict(X_valid)
price_prediction_valid = sc_valid.inverse_transform(price_prediction)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1]))
y_2_valid=model_2_open.predict(X_valid)
y_3_valid=model_3_open.predict(X_valid)
y_4_valid=model_4_open.predict(X_valid)
price_prediction_valid+=(y_2_valid+y_3_valid+y_4_valid)
zeros = np.zeros([WINDOW_SIZE_SEARCH])
price_prediction = np.concatenate((zeros, price_prediction_valid), axis=None)
# Out:
# 22/22 [==============================] - 5s 204ms/step

# %%
price_error = mean_squared_error(valid_set, price_prediction)
print("Price error on the validation set : ", price_error)
# Out:
# Price error on the validation set :  6.989598706145041

# %%
plt.figure(figsize=(15,15))
plt.plot(valid_set, color='red',label='Real Apple Stock Price')
plt.plot(price_prediction, color='blue',label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction on the validation set')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# **Preparing Test Data**

# %%
X_test, y_test = generate_data(test_set_scaled, WINDOW_SIZE_SEARCH)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
price_prediction_test = model_1_open.predict(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1]))
price_error = mean_squared_error(y_test, price_prediction_test)
print("Price error on the test set : ", price_error)
y_2_test=model_2_open.predict(X_test)
y_3_test=model_3_open.predict(X_test)
y_4_test=model_4_open.predict(X_test)
price_prediction_test+=(y_2_test+y_3_test+y_4_test)
price_prediction_test = sc_test.inverse_transform(price_prediction_test)
# Out:
# 66/66 [==============================] - 13s 195ms/step
# Price error on the test set :  0.00014088146039175023

# %%
price_error = mean_squared_error(test_set[WINDOW_SIZE_SEARCH:], price_prediction_test)
print("Price error on the test set : ", price_error)
# Out:
# Price error on the test set :  2.6154125670784287

# %%
zeros = np.zeros([WINDOW_SIZE_SEARCH])
price_prediction_test = np.concatenate((zeros, price_prediction_test), axis=None)
plt.figure(figsize=(15,15))
plt.plot(test_set, color='red',label='Real Apple Stock Price')
plt.plot(price_prediction_test, color='blue',label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction on the test set')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # **Predicting Closing Value**

# %% [markdown]
# **Preparing Train Data**

# %%
df_apple = pd.read_csv("../input/apple-stock-data-updated-till-22jun2021/AAPL.csv")
df_apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
df_apple['Date'] = pd.to_datetime(df_apple['Date'], format="%Y-%m-%d")

# %%
close_price=df_apple.loc[:,'Close'].to_numpy()

# %%
close_price = close_price.reshape(-1, 1)
train_set = close_price[:7000]
valid_set = close_price[7000:8000]
test_set = close_price[8000:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_valid = MinMaxScaler(feature_range=(0, 1))
sc_test = MinMaxScaler(feature_range=(0, 1))

train_set_scaled = sc.fit_transform(train_set)
valid_set_scaled = sc_valid.fit_transform(valid_set)
test_set_scaled = sc_test.fit_transform(test_set)

# %%
def generate_data(data, window_size_input = 300):
    X = []
    y = []
    for i in range(window_size_input, len(data)):
        # Get the data 
        X_data = data[i - window_size_input : i, 0]
        y_data = data[i, 0]
        X.append(X_data)
        y.append(y_data)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE_SEARCH = 300

X_train, y_train = generate_data(train_set_scaled, WINDOW_SIZE_SEARCH)
X_valid, y_valid = generate_data(valid_set_scaled, WINDOW_SIZE_SEARCH)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1], 1))

# %% [markdown]
# **Making Model**

# %%
model_1_close = Sequential()

model_1_close.add(LSTM(256, return_sequences=False, input_shape= (X_train.shape[1], 1)))
model_1_close.add(Dense(128))
model_1_close.add(Dense(64))
model_1_close.add(Dense(1))

model_1_close.compile(optimizer = 'adam', loss = 'mean_squared_error',)

# %%
hist = model_1_close.fit(X_train, y_train, epochs = 10, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/10
# 105/105 - 83s - loss: 0.0010 - 83s/epoch - 787ms/step
# Epoch 2/10
# 105/105 - 92s - loss: 6.5633e-05 - 92s/epoch - 881ms/step
# Epoch 3/10
# 105/105 - 94s - loss: 7.1321e-05 - 94s/epoch - 897ms/step
# Epoch 4/10
# 105/105 - 85s - loss: 7.6621e-05 - 85s/epoch - 806ms/step
# Epoch 5/10
# 105/105 - 76s - loss: 7.9544e-05 - 76s/epoch - 722ms/step
# Epoch 6/10
# 105/105 - 75s - loss: 6.2880e-05 - 75s/epoch - 712ms/step
# Epoch 7/10
# 105/105 - 75s - loss: 6.3262e-05 - 75s/epoch - 714ms/step
# Epoch 8/10
# 105/105 - 78s - loss: 6.3772e-05 - 78s/epoch - 743ms/step
# Epoch 9/10
# 105/105 - 77s - loss: 5.5145e-05 - 77s/epoch - 729ms/step
# Epoch 10/10
# 105/105 - 76s - loss: 5.4630e-05 - 76s/epoch - 727ms/step

# %%
plt.plot(hist.history['loss'])
plt.title('Loss from the Training Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc = 'upper left')
plt.show()

# %%
pred_price_train=model_1_open.predict(X_train)
# Out:
# 210/210 [==============================] - 38s 179ms/step

# %%
y_train=y_train.reshape(len(y_train),1)

# %%
y_2_train=y_train-pred_price_train

# %%
model_2_close=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_2_close.fit(X_train,y_2_train)
y_2_pred=model_2_close.predict(X_train)
pred_price_train+=y_2_pred

# %%
y_3_train=y_train-pred_price_train

# %%
model_3_close=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_3_close.fit(X_train,y_3_train)
y_3_pred=model_3_close.predict(X_train)
pred_price_train+=y_3_pred

# %%
y_4_train=y_train-pred_price_train

# %%
model_4_close=Ridge()
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
model_4_close.fit(X_train,y_4_train)
y_4_pred=model_4_close.predict(X_train)
pred_price_train+=y_4_pred

# %%
print(mean_squared_error(pred_price_train,y_train))
# Out:
# 2.678871252748168e-05

# %% [markdown]
# **Preparing Validation Data**

# %%
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1],1))
price_prediction = model_1_close.predict(X_valid)
price_prediction_valid = sc_valid.inverse_transform(price_prediction)
X_valid = np.reshape(X_valid, (X_valid.shape[0], X_valid.shape[1]))
y_2_valid=model_2_close.predict(X_valid)
y_3_valid=model_3_close.predict(X_valid)
y_4_valid=model_4_close.predict(X_valid)
price_prediction_valid+=(y_2_valid+y_3_valid+y_4_valid)
zeros = np.zeros([WINDOW_SIZE_SEARCH])
price_prediction = np.concatenate((zeros, price_prediction_valid), axis=None)
# Out:
# 22/22 [==============================] - 4s 174ms/step

# %%
price_error = mean_squared_error(valid_set, price_prediction)
print("Price error on the validation set : ", price_error)
# Out:
# Price error on the validation set :  6.990722978970455

# %%
plt.figure(figsize=(15,15))
plt.plot(valid_set, color='red',label='Real Apple Stock Price')
plt.plot(price_prediction, color='blue',label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction on the validation set')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# **Preparing Test Data**

# %%
X_test, y_test = generate_data(test_set_scaled, WINDOW_SIZE_SEARCH)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
price_prediction_test = model_1_close.predict(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1]))
price_error = mean_squared_error(y_test, price_prediction_test)
print("Price error on the test set : ", price_error)
y_2_test=model_2_close.predict(X_test)
y_3_test=model_3_close.predict(X_test)
y_4_test=model_4_close.predict(X_test)
price_prediction_test+=(y_2_test+y_3_test+y_4_test)
price_prediction_test = sc_test.inverse_transform(price_prediction_test)
# Out:
# 66/66 [==============================] - 12s 182ms/step
# Price error on the test set :  9.937352378213778e-05

# %%
price_error = mean_squared_error(test_set[WINDOW_SIZE_SEARCH:], price_prediction_test)
print("Price error on the test set : ", price_error)
# Out:
# Price error on the test set :  2.823762550469121

# %%
zeros = np.zeros([WINDOW_SIZE_SEARCH])
price_prediction_test = np.concatenate((zeros, price_prediction_test), axis=None)
plt.figure(figsize=(15,15))
plt.plot(test_set, color='red',label='Real Apple Stock Price')
plt.plot(price_prediction_test, color='blue',label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction on the test set')
plt.xlabel('Time')
plt.ylabel('Apple Stock Price')
plt.legend()
plt.show()
